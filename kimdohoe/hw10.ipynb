# %%
import numpy as np
import sympy
from sympy import symbol
sympy.init_printing(use_latex='mathjax')

# %%
x= Symbol("x")
a= sympy.Symbol("a")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ed37a4acad33> in <module>
# ----> 1 x= Symbol("x")
#       2 a= sympy.Symbol("a")
#
# NameError: name 'Symbol' is not defined

# %%
sympy.integrate(sympy.exp(-a*x**2),(x,-oo,oo))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4bf873b81b4d> in <module>
# ----> 1 sympy.integrate(sympy.exp(-a*x**2),(x,-oo,oo))
#
# NameError: name 'a' is not defined

# %%
sympy.integrate(x*sympy.exp(-a*x**2),(x,-oo,oo))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1f7d7b806794> in <module>
# ----> 1 sympy.integrate(x*sympy.exp(-a*x**2),(x,-oo,oo))
#
# NameError: name 'x' is not defined

# %%
sympy.integrate((x*x)*sympy.exp(-a*x**2),(x,-oo,oo))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-74f2d86321ed> in <module>
# ----> 1 sympy.integrate((x*x)*sympy.exp(-a*x**2),(x,-oo,oo))
#
# NameError: name 'x' is not defined

# %%
sympy.integrate((x**4)*sympy.exp(-a*x**2),(x,-oo,oo))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-4f333a65dfc2> in <module>
# ----> 1 sympy.integrate((x**4)*sympy.exp(-a*x**2),(x,-oo,oo))
#
# NameError: name 'x' is not defined

# %% [markdown]
# ## x(0)=1 ##
# ## x'(t) = -ax ##

# %%
x= sympy.Function('x')
t= sympy.symbols('t')

# %%
sympy.Eq(x(t).diff(t),-a*x(t))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-725574646712> in <module>
# ----> 1 sympy.Eq(x(t).diff(t),-a*x(t))
#
# NameError: name 'a' is not defined

# %%
sympy.dsolve(sympy.Eq(x(t).diff(t),-a*x(t)),ics={x(0):1})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-de86d48c5f50> in <module>
# ----> 1 sympy.dsolve(sympy.Eq(x(t).diff(t),-a*x(t)),ics={x(0):1})
#
# NameError: name 'a' is not defined

# %%
-10
