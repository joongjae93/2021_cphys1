# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import integrate

# %%
x = np.arange(0,8,0.01)
def y(x):
    return np.sin(x)

# %%
def trapez(f,a,b,n):
    s, x, dx = 0, a, (b-a)/n
    while(x<b):
        s += dx*(0.5*f(x)+0.5*f(x+dx))
        x = x + dx
    return s

def for_diff(f,x,dx):
    return (f(x+dx)-f(x))/dx
def back_diff(f,x,dx):
    return (f(x)-f(x-dx))/dx
def cen_diff(f,x,dx):
    return (f(x+dx/2)-f(x-dx/2))/dx

# %%
dx=0.01
x=np.arange(0,8,0.01)
diff1=[for_diff(y,i,dx) for i in xdata]
diff2=[back_diff(y,i,dx) for i in xdata]
diff3=[cen_diff(y,i,dx) for i in xdata]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-58962d5df903> in <module>
#       1 dx=0.01
#       2 x=np.arange(0,8,0.01)
# ----> 3 diff1=[for_diff(y,i,dx) for i in xdata]
#       4 diff2=[back_diff(y,i,dx) for i in xdata]
#       5 diff3=[cen_diff(y,i,dx) for i in xdata]
#
# NameError: name 'xdata' is not defined

# %%
plt.plot(x,diff1)
plt.plot(x,diff2)
plt.plot(x,diff3)
plt.plot(x,y(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-80f4ccbc5f9f> in <module>
# ----> 1 plt.plot(x,diff1)
#       2 plt.plot(x,diff2)
#       3 plt.plot(x,diff3)
#       4 plt.plot(x,y(x))
#
# NameError: name 'diff1' is not defined

# %%
from scipy.misc import derivative
derivative(np.sin,np.pi*2,dx=0.001)
# Out:
# 0.9999998333336756

# %%
plt.plot(xdata,[derivative(np.sin,i,dx=0.01) for i in xdata])
plt.plot(xdata,[derivative(np.sin,i,dx=0.01,n=2) for i in xdata])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-bc099ff275e4> in <module>
# ----> 1 plt.plot(xdata,[derivative(np.sin,i,dx=0.01) for i in xdata])
#       2 plt.plot(xdata,[derivative(np.sin,i,dx=0.01,n=2) for i in xdata])
#
# NameError: name 'xdata' is not defined

# %%
x = np.arange(0,8,0.01)
def g(x):
    return np.cos(x)

# %%
def trapez1(f1,a1,b1,n1):
    s1, x1, dx1 = 0, a1, (b1-a1)/n1
    while(x<b1):
        s1 += dx1*(0.5*f1(x1)+0.5*f1(x1+dx1))
        x1 = x1 + dx1
    return s1

def for_diff(f1,x1,dx1):
    return (f1(x1+dx1)-f1(x1))/dx1
def back_diff(f1,x1,dx1):
    return (f1(x1)-f1(x1-dx1))/dx1
def cen_diff(f1,x1,dx1):
    return (f1(x1+dx1/2)-f1(x1-dx1/2))/dx1

# %%
dx1=0.01
x1=np.arange(0,8,0.01)
diff1=[for_diff(g,j,dx1) for j in xdata]
diff2=[back_diff(g,j,dx1) for j in xdata]
diff3=[cen_diff(g,j,dx1) for j in xdata]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-639a7a115bb7> in <module>
#       1 dx1=0.01
#       2 x1=np.arange(0,8,0.01)
# ----> 3 diff1=[for_diff(g,j,dx1) for j in xdata]
#       4 diff2=[back_diff(g,j,dx1) for j in xdata]
#       5 diff3=[cen_diff(g,j,dx1) for j in xdata]
#
# NameError: name 'xdata' is not defined

# %%
plt.plot(x1,diff1)
plt.plot(x1,diff2)
plt.plot(x1,diff3)
plt.plot(x1,g(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0f54d151a992> in <module>
# ----> 1 plt.plot(x1,diff1)
#       2 plt.plot(x1,diff2)
#       3 plt.plot(x1,diff3)
#       4 plt.plot(x1,g(x))
#
# NameError: name 'diff1' is not defined

# %%
from scipy.misc import derivative
derivative(np.cos,np.pi*2,dx=0.001)
# Out:
# 0.0

# %%
plt.plot(xdata,[derivative(np.cos,i,dx=0.01) for i in xdata])
plt.plot(xdata,[derivative(np.cos,i,dx=0.01,n=2) for i in xdata])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-6e2f564b7b65> in <module>
# ----> 1 plt.plot(xdata,[derivative(np.cos,i,dx=0.01) for i in xdata])
#       2 plt.plot(xdata,[derivative(np.cos,i,dx=0.01,n=2) for i in xdata])
#
# NameError: name 'xdata' is not defined

# %%
(-3)
