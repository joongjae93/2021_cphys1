# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import integrate
import math

# %%
def y(x):
    return np.sin(x)

def trapez(f,a,b,n):
    s, x, dx = 0, a, (b-a)/n
    while(x<b):
        s += dx*(0.5*f(x)+0.5*f(x+dx))
        x = x + dx
    return s

trapez(y,0,np.pi,100)
# Out:
# 1.9993421048376274

# %%
def y(x):
    return np.sin(x)
integrate.quad(y,0,np.pi*2)
# Out:
# (2.221501482512777e-16, 4.3998892617845996e-14)

# %%
x = np.arange(0, 2*np.pi, 0.5)

plt.plot(x, y(x), color='black',marker='o')
plt.fill_between(x,y(x),alpha=0.2)

# %%
z=[j for j in range(-20,20)]
c= [trapez(y,0,x,100) for x in range(-20,20)]
plt.plot(z,c)

# %%
def g(x1):
    return np.cos(x1)

def trapez(f1,a1,b1,n1):
    s1, x1, dx1 = 0, a1, (b1-a1)/n1
    while(x1<b1):
        s1 += dx1*(0.5*f1(x1)+0.5*f1(x1+dx1))
        x1 = x1 + dx1
    return s1

trapez(y,0,np.pi*2,100)
# Out:
# 0.0019726223486723616

# %%
def g(x1):
    return np.cos(x1)
integrate.quad(y,0,np.pi*2)
# Out:
# (2.221501482512777e-16, 4.3998892617845996e-14)

# %%
x = np.arange(0, 2*np.pi, 0.5)

plt.plot(x, g(x), color='black',marker='o',label='sin')
plt.fill_between(x,g(x),alpha=0.2)

# %%
q=[t for t in range(-20,20)]
p= [trapez(g,0,b,100) for b in range(-20,20)]
plt.plot(q,p)

# %% [markdown]
# 적분 결과를 그래프로 보여주는 것이 과제 (-2)
