# %% [markdown]
# # 1. Pendulum

# %% [markdown]
# 다음처럼 주어지는 진자의 운동방정식을 풀어라.$$ \frac{d^2 \theta}{dt^2}  + \frac{g}{L} \sin \theta = 0. $$
#
# $\beta$는 마찰의 세기, $L$은 진자의 길이, $g$는 중력가속도이다. 흔히 작은 $\theta$를 가정하고 $\sin\theta \approx \theta$ 근사를 이용하여 해석적인 해를 구한다. 여기에서는 $\sin \theta$를 직접 이용하여 수치해를 구해보자.
#
# 2차 미분방정식을 2개의 1차 미분방정식으로 분리하자.$$ \frac{d\theta}{dt} = w, \\
# \frac{d w}{dt} = - \frac{g}{L} \sin \theta . $$
#
# $\frac{g}{L}=1$을 가정하고 운동의 해를 구해보자. scipy.integrate.odeint를 포함하여 어떤 방법을 이용하여도 된다.

# %%
import numpy as np

g, L = 9.8, 9.8
dt=0.01
t = np.arange(0,50,dt)
theta, w = np.array([]), np.array([])

theta0, w0 = 1, 0

for i in t:
    theta0 = theta0 + dt*w0
    w0 = w0 -dt*(g/L)*theta0
    theta=np.append(theta,theta0)
    w=np.append(w,w0)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(t,theta)

# %% [markdown]
# # 2. Pendulum (small oscillations)

# %% [markdown]
# 1번 문제와 같은 진자에 대해 평형점 근처에서 조금씩 진동하고 있는 상황을 고려하자. 그러면
# $\sin\theta \approx \theta$ 근사를 적용할 수 있다.
#
# 이 경우는 다음과 같은 2개의 1차 미분방정식을 얻는다.$$ \frac{d\theta}{dt} = w, \\
# \frac{d w}{dt} =  - \frac{g}{L} \theta . $$
#
# $\frac{g}{L}=1$을 가정하고 운동의 해를 구해보자. scipy.integrate.odeint를 포함하여 어떤 방법을 이용하여도 된다. 초기 조건 $\theta_o, w_o$를 바꾸어 가면서 1번 문제의 결과와 비교해보자.

# %%
#theta0=1인 경우(1번 문제)

import numpy as np

g, L = 9.8, 9.8
dt=0.01
t = np.arange(0,50,dt)
theta, w = np.array([]), np.array([])

theta0, w0 = 1, 0

for i in t:
    theta0 = theta0 + dt*w0
    w0 = w0 -dt*(g/L)*theta0
    theta=np.append(theta,theta0)
    w=np.append(w,w0)

# %%
#theta0=2인 경우

import numpy as np

g, L = 9.8, 9.8
dt=0.01

t = np.arange(0,50,dt)

theta1, w1 = np.array([]), np.array([])


theta01, w01 = 2, 0

for i in t:
    theta01 = theta01 + dt*w01
    w01 = w01 -dt*(g/L)*theta01
    theta1=np.append(theta1,theta01)
    w1=np.append(w1,w01)

# %%
#theta0=3인 경우

import numpy as np

g, L = 9.8, 9.8
dt=0.01

t = np.arange(0,50,dt)
theta2, w2 = np.array([]), np.array([])

theta02, w02 = 3, 0

for i in t:
    theta02 = theta02 + dt*w02
    w02 = w02 -dt*(g/L)*theta02
    theta2=np.append(theta2,theta02)
    w2=np.append(w2,w02)

# %%
#theta0=4인 경우

import numpy as np

g, L = 9.8, 9.8
dt=0.01

t = np.arange(0,50,dt)
theta3, w3 = np.array([]), np.array([])

theta03, w03 = 4, 0

for i in t:
    theta03 = theta03 + dt*w03
    w03 = w03 -dt*(g/L)*theta03
    theta3=np.append(theta3,theta03)
    w3=np.append(w3,w03)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(t,theta,label='$theta0=1$')
plt.plot(t,theta1,label='$theta0=2$')
plt.plot(t,theta2,label='$theta0=3$')
plt.plot(t,theta3,label='$theta0=4$')
plt.legend()

#w0를 고정하고 theta0를 키울 경우 theta0의 값이 클수록 진폭이 커진다.

# %%
#w0=0인 경우(1번 문제)

import numpy as np

g, L = 9.8, 9.8
dt=0.001
t = np.arange(0,50,dt)
theta, w = np.array([]), np.array([])

theta0, w0 = 1, 0

for i in t:
    theta0 = theta0 + dt*w0
    w0 = w0 -dt*(g/L)*theta0
    theta=np.append(theta,theta0)
    w=np.append(w,w0)

# %%
#w0=1인 경우

import numpy as np

g, L = 9.8, 9.8
dt=0.001

t = np.arange(0,50,dt)
theta4, w4 = np.array([]), np.array([])


theta04, w04 = 1, 1

for i in t:
    theta04 = theta04 + dt*w04
    w04 = w04 -dt*(g/L)*theta04
    theta4=np.append(theta4,theta04)
    w4=np.append(w4,w04)

# %%
#w=2인 경우

import numpy as np

g, L = 9.8, 9.8
dt=0.001

t = np.arange(0,50,dt)
theta5, w5 = np.array([]), np.array([])

theta05, w05 = 1, 2

for i in t:
    theta05 = theta05 + dt*w05
    w05 = w05 -dt*(g/L)*theta05
    theta5=np.append(theta5,theta05)
    w5=np.append(w5,w05)

# %%
#w=3인 경우

import numpy as np

g, L = 9.8, 9.8
dt=0.001

t = np.arange(0,50,dt)
theta6, w6 = np.array([]), np.array([])

theta06, w06 = 1, 3

for i in t:
    theta06 = theta06 + dt*w06
    w06 = w06 -dt*(g/L)*theta06
    theta6=np.append(theta6,theta06)
    w6=np.append(w6,w06)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot(t,theta,label='$w0=0$')
plt.plot(t,theta4,label='$w0=1$')
plt.plot(t,theta5,label='$w0=2$')
plt.plot(t,theta6,label='$w0=3$')
plt.legend()

#theta0를 고정하고 w0를 변하시킬 경우 위상각이 달라지는 효과를 볼 수 있다.

# %% [markdown]
# # 3. Damped Pendulum

# %% [markdown]
# 다음처럼 주어지는 damped 진자의 운동방정식을 풀어라.$$ \frac{d^2 \theta}{dt^2} + \beta \frac{d \theta}{dt} + \frac{g}{L} \sin \theta = 0. $$$\beta$는 마찰의 세기, $L$은 진자의 길이, $g$는 중력가속도이다.
#
# 우선 2차 미분방정식을 2개의 1차 미분방정식으로 분리해 보자.$$ \frac{d\theta}{dt} = w, \\
# \frac{d w}{dt} = - \beta w - \frac{g}{L} \sin \theta . $$
#
# 초기 상태는 $\theta_0 = 1, w_0 =0$이며 $\beta=0.1, \frac{g}{L}=1$을 가정하고 운동의 해를 구해보자. scipy.integrate.odeint를 포함하여 어떤 방법을 이용하여도 된다.

# %%
import numpy as np

g, L, beta = 9.8, 9.8, 0.1
dt=0.01
t = np.arange(0,50,dt)
theta, w = np.array([]), np.array([])

theta0, w0 = 1, 0

for i in t:
    theta0 = theta0 + dt*w0
    w0 = w0 -dt*beta*w0-dt*(g/L)*theta0
    theta=np.append(theta,theta0)
    w=np.append(w,w0)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(t,theta)

# %% [markdown]
# # 4. Forced Pendulum

# %% [markdown]
# 다음처럼 주어지는 forced 진자의 운동방정식을 풀어라.$$ \frac{d^2 \theta}{dt^2} + \beta \frac{d \theta}{dt} + \frac{g}{L} \sin \theta = A \cos (v t). $$$\beta$는 마찰의 세기, $L$은 진자의 길이, $g$는 중력가속도, $A$는 외부에서 주어지는 힘의 진폭, $v$는 외부에서 주어지는 힘의 진동수이다.
#
# forced 진자의 움직임을 구해보고 $v$의 효과에 대해 살펴보아라.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

#v=2인 경우

g, L, beta, v, A = 9.8, 9.8, 0.1, 2, 1
state0 = [1.0, 0.0]
t = np.arange(0.0, 50.0, 0.001)

def f1(state, t):
    theta, w = state 
    return w, -beta*w-(g/L)*np.sin(theta)+A*np.cos(v*t)

states1 = odeint(f1, state0, t)

# %%
#v=3인 경우

g, L, beta, v, A = 9.8, 9.8, 0.1, 3, 1
state0 = [1.0, 0.0]
t = np.arange(0.0, 50.0, 0.001)

def f2(state, t):
    theta, w = state 
    return w, -beta*w-(g/L)*np.sin(theta)+A*np.cos(v*t)

states2 = odeint(f2, state0, t)

# %%
#v=4인 경우

g, L, beta, v, A = 9.8, 9.8, 0.1, 4, 1
state0 = [1.0, 0.0]
t = np.arange(0.0, 50.0, 0.001)

def f3(state, t):
    theta, w = state 
    return w, -beta*w-(g/L)*np.sin(theta)+A*np.cos(v*t)

states3 = odeint(f3, state0, t)

# %%
#v=10인 경우

g, L, beta, v, A = 9.8, 9.8, 0.1, 10, 1
state0 = [1.0, 0.0]
t = np.arange(0.0, 50.0, 0.001)

def f4(state, t):
    theta, w = state 
    return w, -beta*w-(g/L)*np.sin(theta)+A*np.cos(v*t)

states4 = odeint(f4, state0, t)

# %%
import numpy as np

g, L, beta = 9.8, 9.8, 0.1
dt=0.001
t = np.arange(0,50,dt)
theta, w = np.array([]), np.array([])

theta0, w0 = 1, 0

for i in t:
    theta0 = theta0 + dt*w0
    w0 = w0 -dt*beta*w0-dt*(g/L)*theta0
    theta=np.append(theta,theta0)
    w=np.append(w,w0)

# %%
plt.plot(t,states1[:,0],label='$v=2$')
plt.plot(t,states2[:,0],label='$v=3$')
plt.plot(t,states3[:,0],label='$v=4$')
plt.plot(t,states4[:,0],label='$v=10$')
plt.plot(t,theta,label='$damped$')
plt.legend()

#따라서 v가 커질수록 dampedpendulum의 운동과 같은 운동을 한다는 것을 알 수 있다.
# Out:
# C:\Users\kook\Anaconda3\lib\site-packages\IPython\core\events.py:88: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# C:\Users\kook\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# -4
#
# 1번 - theta 가 아니라 np.sin(theta) 여야 함.
#
# 2번 - theta 와 np.sin(theta)의 결과를 비교하는 것이 목적
#
# 4번 - A*np.cos(v*t)*dt 가 되어야 함
