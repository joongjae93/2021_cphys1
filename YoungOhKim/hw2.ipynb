# %%
def logistic(r,s) :
 x = 0
 while(x<20):
  s = r*s*(1-s)
  x = x+1
  print(r,s)
  return r*s(1-s)
 return logistic(r,s)

# %%
logistic (4.5, 0.5)

logistic (4.5, 0.51)

logistic (4.5, 0.51)
# Out:
# 4.5 1.125
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-4ddb063ef23f> in <module>()
# ----> 1 logistic (4.5, 0.5)
#       2
#       3 logistic (4.5, 0.51)
#       4
#       5 logistic (4.5, 0.51)
#
# <ipython-input-9-fb6adcb2184c> in logistic(r, s)
#       5   x = x+1
#       6   print(r,s)
# ----> 7   return r*s(1-s)
#       8  return logistic(r,s)
#
# TypeError: 'float' object is not callable

# %%
def Fib(n) :
 if n <= 1 :
  return 1
 if n <= 2 :
   return 1 
 return Fib(n-1)+Fib(n-2)

# %%
Fib(3), Fib(6), Fib(9), Fib(12)
# Out:
# (2, 8, 34, 144)

# %% [markdown]
# 로지스틱(-5) 함수도 잘못되었고(에러는 r*s(1-s) -> r*s*(1-s) 로 수정하면 해결됨)
# 에러를 해결해도 올바른 결과를 얻을 수 없음
#
# 그리고 제출은 ipynb 파일로 해주세요
