# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %%
g = 10
L = 10
state0 = [1.0, 0.0]
t = np.arange(0.0, 50.0, 0.01)

def f(state, t):
    theta, w = state 
    return w, -(g/L)*np.sin(theta)

states = odeint(f, state0, t)
plt.plot(t,states[:,0])

# %%
g, L = 10, 10
dt=0.001
t = np.arange(0,50,dt)
theta , w = np.array([]), np.array([])
theta0, w0 = 1, 0

for i in t:
    theta0 = theta0 + dt*w0
    w0 = w0 - dt*g*theta0/L
    theta=np.append(theta,theta0)
    w=np.append(w,w0)

plt.plot(t,theta)

# %%
g, L = 10, 10
dt=0.001
t = np.arange(0,50,dt)
theta , w = np.array([]), np.array([])
theta0, w0 = 1, 1

for i in t:
    theta0 = theta0 + dt*w0
    w0 = w0 - dt*g*theta0/L
    theta=np.append(theta,theta0)
    w=np.append(w,w0)

plt.plot(t,theta)

# %%
g, L = 10, 10
dt=0.001
t = np.arange(0,50,dt)
theta , w = np.array([]), np.array([])
theta0, w0 = 1, 2

for i in t:
    theta0 = theta0 + dt*w0
    w0 = w0 - dt*g*theta0/L
    theta=np.append(theta,theta0)
    w=np.append(w,w0)

plt.plot(t,theta)

# %%
g, L = 10, 10
dt=0.001
t = np.arange(0,50,dt)
theta , w = np.array([]), np.array([])
theta0, w0 = 2, 0

for i in t:
    theta0 = theta0 + dt*w0
    w0 = w0 - dt*g*theta0/L
    theta=np.append(theta,theta0)
    w=np.append(w,w0)

plt.plot(t,theta)

# %%
g, L = 10, 10
dt=0.001
t = np.arange(0,50,dt)
theta , w = np.array([]), np.array([])
theta0, w0 = 3, 0

for i in t:
    theta0 = theta0 + dt*w0
    w0 = w0 - dt*g*theta0/L
    theta=np.append(theta,theta0)
    w=np.append(w,w0)

plt.plot(t,theta)

# %%
theta0, w0이 1, 0일때 1번 문제의 결과와 같다. theta0이 커지면 진폭이 n배 증가하고 w0이 커지면 위상이 느려진다.

# %%
beta, g, L = 0.1, 10, 10
dt=0.01
t = np.arange(0,100,dt)
theta , w = np.array([]), np.array([])
theta0, w0 = 1, 0

for i in t:
    theta0 = theta0 + dt*w0
    w0 = w0 - dt*beta*w0 - dt*g*np.sin(theta0)/L
    theta=np.append(theta,theta0)
    w=np.append(w,w0)

plt.plot(t,theta)

# %%
g = 10
L = 10
beta = 0.1
A = 1
v = 1
state0 = [1.0, 0.0]
t = np.arange(0.0, 50.0, 0.01)

def f(state, t):
    theta, w = state 
    return w, A*np.cos(v*t)-beta*w-(g/L)*np.sin(theta)

states = odeint(f, state0, t)
plt.plot(t,states[:,0])

# %%
g = 10
L = 10
beta = 0.1
A = 1
v = 2
state0 = [1.0, 0.0]
t = np.arange(0.0, 50.0, 0.01)

def f(state, t):
    theta, w = state 
    return w, A*np.cos(v*t)-beta*w-(g/L)*np.sin(theta)

states = odeint(f, state0, t)
plt.plot(t,states[:,0])

# %%
g = 10
L = 10
beta = 0.1
A = 1
v = 3
state0 = [1.0, 0.0]
t = np.arange(0.0, 50.0, 0.01)

def f(state, t):
    theta, w = state 
    return w, A*np.cos(v*t)-beta*w-(g/L)*np.sin(theta)

states = odeint(f, state0, t)
plt.plot(t,states[:,0])

# %%
g = 10
L = 10
beta = 0.1
A = 1
v = 8
state0 = [0.0, 1.0]
t = np.arange(0.0, 50.0, 0.01)

def f(state, t):
    theta, w = state 
    return w, A*np.cos(v*t)-beta*w-(g/L)*np.sin(theta)

states = odeint(f, state0, t)
plt.plot(t,states[:,0])

# %%
g = 10
L = 10
beta = 0.1
A = 1
v = 20
state0 = [1.0, 0.0]
t = np.arange(0.0, 50.0, 0.01)

def f(state, t):
    theta, w = state 
    return w, A*np.cos(v*t)-beta*w-(g/L)*np.sin(theta)

states = odeint(f, state0, t)
plt.plot(t,states[:,0])

# %%
v가 커짐에 따라 forced 진자의 움직임은 Damped pendulum의 움직임과 같아진다.

# %% [markdown]
# -2
#
# 2번 문항에서 theta를 썼을 때와 np.sin(theta)를 썼을 때의 비교가 없고
#
# 4번 문항에서 제출한 것과 같은 경우는 그냥 외부 구동력의 효과가 없는 경우나 다름없음
