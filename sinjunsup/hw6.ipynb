# %% [markdown]
# ## 1. Pendulum

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dt=0.001 #a 는 세타 , w는 위상
t = np.arange(0,100,dt)
a , w = np.array([]), np.array([])
a0, w0 = 1, 0 # 초기위치, 초기위상

for i in t:
    a0 = a0 + dt*w0
    w0 = w0 - dt*1*np.sin(a0) # g/L 은 1로 가정
    a=np.append(a,a0)
    w=np.append(w,w0)

# %%
plt.plot(t,a)

# %% [markdown]
# ## 2. Pendulum (small oscillations)

# %%
dt=0.01 #a 는 세타 , w는 위상
t = np.arange(0,100,dt)
a , w = np.array([]), np.array([])
a0, w0 = 1, 0 # 초기위치, 초기위상

for i in t:
    a0 = a0 + dt*w0
    w0 = w0 - dt*1*a0 # g/L 은 1로 가정
    a=np.append(a,a0)
    w=np.append(w,w0)

# %%
plt.plot(t,a)

# %%
dt=0.01 #a 는 세타 , w는 위상
t = np.arange(0,100,dt)
a , w = np.array([]), np.array([])
a0, w0 = 5, 0 # 초기위치5, 초기위상

for i in t:
    a0 = a0 + dt*w0
    w0 = w0 - dt*1*a0 # g/L 은 1로 가정
    a=np.append(a,a0)
    w=np.append(w,w0)
plt.plot(t,a)

# %%
dt=0.01 #a 는 세타 , w는 위상
t = np.arange(0,100,dt)
a , w = np.array([]), np.array([])
a0, w0 = 20, 0 # 초기위치20, 초기위상
for i in t:
    a0 = a0 + dt*w0
    w0 = w0 - dt*1*a0 # g/L 은 1로 가정
    a=np.append(a,a0)
    w=np.append(w,w0)
plt.plot(t,a)

# %%
dt=0.01 #a 는 세타 , w는 위상
t = np.arange(0,100,dt)
a , w = np.array([]), np.array([])
a0, w0 = 1, 5 # 초기위치1, 초기위상5

for i in t:
    a0 = a0 + dt*w0
    w0 = w0 - dt*1*a0 # g/L 은 1로 가정
    a=np.append(a,a0)
    w=np.append(w,w0)
plt.plot(t,a)

# %%
dt=0.01 #a 는 세타 , w는 위상
t = np.arange(0,100,dt)
a , w = np.array([]), np.array([])
a0, w0 = 1, 20 # 초기위치1, 초기위상20

for i in t:
    a0 = a0 + dt*w0
    w0 = w0 - dt*1*a0 # g/L 은 1로 가정
    a=np.append(a,a0)
    w=np.append(w,w0)
plt.plot(t,a)

# %% [markdown]
# ## 3. Damped Pendulum

# %%
dt=0.01 #a 는 세타 , w는 위상
t = np.arange(0,100,dt)
a , w = np.array([]), np.array([])
a0, w0 = 1, 0 # 초기위치1, 초기위상

for i in t:
    a0 = a0 + dt*w0
    w0 = w0 - dt*w0*b - dt*1*np.sin(a0) # g/L 은 1로 가정
    a=np.append(a,a0)
    w=np.append(w,w0)
plt.plot(t,a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-c1f0763eea66> in <module>
#       6 for i in t:
#       7     a0 = a0 + dt*w0
# ----> 8     w0 = w0 - dt*w0*b - dt*1*np.sin(a0) # g/L 은 1로 가정
#       9     a=np.append(a,a0)
#      10     w=np.append(w,w0)
#
# NameError: name 'b' is not defined

# %% [markdown]
# ## 4. Forced Pendulum

# %%
dt=0.01 #a 는 세타 , w는 위상
A, v = 1,1 #A는 외부힘 v는 외부진동수
g,l= 1,1  #g 중력가속도  ,l 진자의 길이
t = np.arange(0,100,dt)
a , w = np.array([]), np.array([])
a0, w0 = 1, 0 # 초기위치1,초기위상
b= 0.1 

for i in t:
    a0 = a0 + dt*w0
    w0 = w0 - dt*w0*b - dt*(g/l)*np.sin(a0) + A*np.cos(v*i)
    a=np.append(a,a0)
    w=np.append(w,w0)
plt.plot(t,a)

# %%
dt=0.001 #a 는 세타 , w는 위상
A, v = 1,2 #A는 외부힘 v는 외부진동수2
g,l= 1,1 #g 중력가속도  ,l 진자의 길이
t = np.arange(0,100,dt)
a , w = np.array([]), np.array([])
a0, w0 = 1, 0 # 초기위치1, 초기위상
b= 0.1 

for i in t:
    a0 = a0 + dt*w0
    w0 = w0 - dt*w0*b - dt*(g/l)*np.sin(a0) + A*np.cos(v*i)
    a=np.append(a,a0)
    w=np.append(w,w0)
plt.plot(t,a)

# %%
dt=0.001 #a 는 세타 , w는 위상
A, v = 1,5 #A는 외부힘 v는 외부진동수5
g,l= 1,1 #g 중력가속도  ,l 진자의 길이
t = np.arange(0,100,dt)
a , w = np.array([]), np.array([])
a0, w0 = 1, 0 # 초기위치1, 초기위상
b= 0.1 

for i in t:
    a0 = a0 + dt*w0
    w0 = w0 - dt*w0*b - dt*(g/l)*np.sin(a0) + A*np.cos(v*i)
    a=np.append(a,a0)
    w=np.append(w,w0)
plt.plot(t,a)

# %%
dt=0.001 #a 는 세타 , w는 위상
A, v = 1,8 #A는 외부힘 v는 외부진동수8
g,l= 1,1 #g 중력가속도  ,l 진자의 길이
t = np.arange(0,100,dt)
a , w = np.array([]), np.array([])
a0, w0 = 1, 0 # 초기위치1, 초기위상
b= 0.1 

for i in t:
    a0 = a0 + dt*w0
    w0 = w0 - dt*w0*b - dt*(g/l)*np.sin(a0) + A*np.cos(v*i)
    a=np.append(a,a0)
    w=np.append(w,w0)
plt.plot(t,a)

# %% [markdown]
# 외부진동수v 의 역할은 알짜 진동수,진폭을 결정한다고 볼수있다.

# %% [markdown]
# -5
#
# 2번 문항에서 theta를 썼을 때와 np.sin(theta)를 썼을 때의 비교가 없고 4번 문항에서 A*np.cos(v*i)*dt 가 되어야 함
