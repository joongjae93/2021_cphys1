# %% [markdown]
# ## Gaussian Integral

# %%
import numpy as np
import sympy
from sympy import *
sympy.init_printing(use_latex='mathjax')

# %% [markdown]
# ## 1

# %%
x= sympy.symbols("x")

sympy.integrate(sympy.exp(-a*x**2),(x,-oo,oo))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-cd7dfa74d2b3> in <module>
#       1 x= sympy.symbols("x")
#       2
# ----> 3 sympy.integrate(sympy.exp(-a*x**2),(x,-oo,oo))
#
# NameError: name 'a' is not defined

# %% [markdown]
# ## 2

# %%
x= sympy.symbols("x")

sympy.integrate(x*sympy.exp(-a*x**2),(x,-oo,oo))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-439dce3a8b0f> in <module>
#       1 x= sympy.symbols("x")
#       2
# ----> 3 sympy.integrate(x*sympy.exp(-a*x**2),(x,-oo,oo))
#
# NameError: name 'a' is not defined

# %% [markdown]
# ## 3

# %%
x= sympy.symbols("x")

sympy.integrate((x**2)*sympy.exp(-a*x**2),(x,-oo,oo))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8eddfaa20940> in <module>
#       1 x= sympy.symbols("x")
#       2
# ----> 3 sympy.integrate((x**2)*sympy.exp(-a*x**2),(x,-oo,oo))
#
# NameError: name 'a' is not defined

# %% [markdown]
# ## 4

# %%
x= sympy.symbols("x")

sympy.integrate((x**4)*sympy.exp(-a*x**2),(x,-oo,oo))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-93d19dfb20b8> in <module>
#       1 x= sympy.symbols("x")
#       2
# ----> 3 sympy.integrate((x**4)*sympy.exp(-a*x**2),(x,-oo,oo))
#
# NameError: name 'a' is not defined

# %% [markdown]
# ## 미분방정식

# %%
t = symbols('t')
x = Function('x')

# %%
dsolve(Eq(x(t).diff(t),-a*x(t)),ics= {x(0):1})# 초기조건 x(0) = 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2d500eeead8b> in <module>
# ----> 1 dsolve(Eq(x(t).diff(t),-a*x(t)),ics= {x(0):1})# 초기조건 x(0) = 1
#
# NameError: name 'a' is not defined

# %%
-10
