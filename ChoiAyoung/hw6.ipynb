# %% [markdown]
# ## 1. Pendulum

# %%
import numpy as np
L, g = 9.8, 9.8
dt=0.001
t = np.arange(0,100,dt)
w , theta = np.array([]), np.array([])
w0, theta0 = 1, np.pi

for i in t:
    theta0 = theta0 + dt*w0
    w0 = w0 - dt*(g/L)*np.sin(theta0)
    theta=np.append(theta,theta0)
    w=np.append(w,w0)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.xlim(0,50);plt.ylim(0,80)
plt.plot(t,theta);

# %% [markdown]
# theta가 pi일 때는 주기가 무한대이다.

# %%
import numpy as np
L, g = 9.8, 9.8
dt=0.001
t = np.arange(0,100,dt)
w , theta = np.array([]), np.array([])
w0, theta0 = 1, np.pi/3

for i in t:
    theta0 = theta0 + dt*w0
    w0 = w0 - dt*(g/L)*np.sin(theta0)
    theta=np.append(theta,theta0)
    w=np.append(w,w0)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(t,theta);

# %% [markdown]
# ## 2. Pendulum (small oscillations)

# %%
#초기조건w0, theta0 = 1, (np.pi)/180

import numpy as np
L, g = 9.8, 9.8
dt=0.001
t = np.arange(0,100,dt)
w , theta = np.array([]), np.array([])
w0, theta0 = 1, (np.pi)/180

for i in t:
    theta0 = theta0 + dt*w0
    w0 = w0 - dt*(g/L)*theta0
    theta=np.append(theta,theta0)
    w=np.append(w,w0)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(t,theta);

# %%
#초기조건 w0, theta0 = 10, (np.pi)/175

import numpy as np
L, g = 9.8, 9.8
dt=0.001
t = np.arange(0,100,dt)
w , theta = np.array([]), np.array([])
w0, theta0 = 10, (np.pi)/175

for i in t:
    theta0 = theta0 + dt*w0
    w0 = w0 - dt*(g/L)*theta0
    theta=np.append(theta,theta0)
    w=np.append(w,w0)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(t,theta);

# %%
#초기조건 w0, theta0 = 0.5, (np.pi)/170

import numpy as np
L, g = 9.8, 9.8
dt=0.001
t = np.arange(0,100,dt)
w , theta = np.array([]), np.array([])
w0, theta0 = 0.5, (np.pi)/170

for i in t:
    theta0 = theta0 + dt*w0
    w0 = w0 - dt*(g/L)*theta0
    theta=np.append(theta,theta0)
    w=np.append(w,w0)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(t,theta);

# %% [markdown]
# ## 3. Damped Pendulum

# %%
import numpy as np
beta, L, g =0.1, 9.8, 9.8
dt=0.001
t = np.arange(0,100,dt)
w , theta = np.array([]), np.array([])
w0, theta0 = 1, 1

for i in t:
    theta0 = theta0 + dt*w0
    w0 = w0 - dt*(beta*w0+(g/L)*np.sin(theta0))
    theta=np.append(theta,theta0)
    w=np.append(w,w0)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(t,theta);

# %% [markdown]
# ## 4. Forced Pendulum

# %%
#v=1

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
beta, L, g =0.1, 9.8, 9.8
A, v = 1, 1
w=1
state0 = [1.0, 0.0]
t = np.arange(0.0, 100.0, 0.001)

def f(state, t):
    theta, s = state 
    return s, A*np.cos(v*t)-beta*s-(g/L)*np.sin(theta)

states = odeint(f, state0, t)
plt.plot(t,states[:,0]);

# %%
#v=0.1

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
beta, L, g =0.1, 9.8, 9.8
A, v = 1, 0.1
w=1
state0 = [1.0, 0.0]
t = np.arange(0.0, 100.0, 0.001)

def f(state, t):
    theta, s = state 
    return s, A*np.cos(v*t)-beta*s-(g/L)*np.sin(theta)

states = odeint(f, state0, t)
plt.plot(t,states[:,0]);

# %%
#v=50

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
beta, L, g =0.1, 9.8, 9.8
A, v = 1, 50
w=1
state0 = [1.0, 0.0]
t = np.arange(0.0, 100.0, 0.001)

def f(state, t):
    theta, s = state 
    return s, A*np.cos(v*t)-beta*s-(g/L)*np.sin(theta)

states = odeint(f, state0, t)
plt.plot(t,states[:,0]);

# %%
#v=10

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
beta, L, g =0.1, 9.8, 9.8
A, v = 1, 10
w=1
state0 = [1.0, 0.0]
t = np.arange(0.0, 100.0, 0.001)

def f(state, t):
    theta, s = state 
    return s, A*np.cos(v*t)-beta*s-(g/L)*np.sin(theta)

states = odeint(f, state0, t)
plt.plot(t,states[:,0]);

# %% [markdown]
# -2 - 2번 결과를 1번과 비교하려면 충분히 큰 theta를 주어야 함, 4번에서 결국 v의 효과는 무엇인가요?
