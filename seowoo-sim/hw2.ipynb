# %%
import numpy as np

# %%
def Logistic(n,r,f0):
    if n==0:
        return f0
    else:
        f=f0
        for i in range(n):
            f=r*f*(1-f)
        return f

# %%
result1=[]
for n in range(21):
    result1.append(logistic(n,4.5,0.5))
print(result1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-83f00b3c6ab9> in <module>
#       1 result1=[]
#       2 for n in range(21):
# ----> 3     result1.append(logistic(n,4.5,0.5))
#       4 print(result1)
#
# NameError: name 'logistic' is not defined

# %%
result2=[]
for n in range(21):
    result2.append(logistic(n,4.5,0.51))
print(result2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-04addd39bf03> in <module>
#       1 result2=[]
#       2 for n in range(21):
# ----> 3     result2.append(logistic(n,4.5,0.51))
#       4 print(result2)
#
# NameError: name 'logistic' is not defined

# %%
result3=[]
for n in range(21):
    result3.append(logistic(n,4.5,0.501))
print(result3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f4987f46cf12> in <module>
#       1 result3=[]
#       2 for n in range(21):
# ----> 3     result3.append(logistic(n,4.5,0.501))
#       4 print(result3)
#
# NameError: name 'logistic' is not defined

# %%
def Fibonacci(n):
    if n==1 or n==2:
        return 1
    else:
        f_1=1
        f_2=1
        for i in range(n-2):
            new=f_1+f_2
            f_2=f_1
            f_1=X
        return X

# %%
로지스틱 실행 안 됨(-3) 함수 작성 부분까지는 부분 점수를 주겠음
피보나치 실행 안 됨(-5)
