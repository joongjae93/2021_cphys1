# %% [markdown]
# ###3월10일 전산물리학 과제

# %%
r=0.5
f[0]=0.5
for n in range(11):
    f[n+1]=r*f[n]*(1-f[n])
    print(f[n])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e699f9e8b481> in <module>
#       1 r=0.5
# ----> 2 f[0]=0.5
#       3 for n in range(11):
#       4     f[n+1]=r*f[n]*(1-f[n])
#       5     print(f[n])
#
# NameError: name 'f' is not defined

# %%
r=2.5
f[0]=0.5
for n in range(11):
    f[n+1]=r*f[n]*(1-f[n])
    print(f[n])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-554f60514b3d> in <module>
#       1 r=2.5
# ----> 2 f[0]=0.5
#       3 for n in range(11):
#       4     f[n+1]=r*f[n]*(1-f[n])
#       5     print(f[n])
#
# NameError: name 'f' is not defined

# %%
r=4.5
f[0]=0.5
for n in range(11):
    f[n+1]=r*f[n]*(1-f[n])
    print(f[n])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-723ee20e987d> in <module>
#       1 r=4.5
# ----> 2 f[0]=0.5
#       3 for n in range(11):
#       4     f[n+1]=r*f[n]*(1-f[n])
#       5     print(f[n])
#
# NameError: name 'f' is not defined

# %%
r=4.5
f[0]=0.51
for n in range(11):
    f[n+1]=r*f[n]*(1-f[n])
    print(f[n])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-91426187155c> in <module>
#       1 r=4.5
# ----> 2 f[0]=0.51
#       3 for n in range(11):
#       4     f[n+1]=r*f[n]*(1-f[n])
#       5     print(f[n])
#
# NameError: name 'f' is not defined

# %% [markdown]
# 실행 안 됨(-10)
