# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# 1번

# %%
sx=np.array([[0,1],[1,0]])
ex=np.linalg.eig(s_x)
print(ex)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-355f13979065> in <module>
#       1 sx=np.array([[0,1],[1,0]])
# ----> 2 ex=np.linalg.eig(s_x)
#       3 print(ex)
#
# NameError: name 's_x' is not defined

# %%
sy=np.array([[0,-1j],[1j,0]])
ey=np.linalg.eig(s_y)
print(ey)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6c97e4c5e461> in <module>
#       1 sy=np.array([[0,-1j],[1j,0]])
# ----> 2 ey=np.linalg.eig(s_y)
#       3 print(ey)
#
# NameError: name 's_y' is not defined

# %%
sz=np.array([[1,0],[0,-1]])
ez=np.linalg.eig(s_z)
print(ez)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3cb8ca290c4e> in <module>
#       1 sz=np.array([[1,0],[0,-1]])
# ----> 2 ez=np.linalg.eig(s_z)
#       3 print(ez)
#
# NameError: name 's_z' is not defined

# %% [markdown]
# 2번

# %%
sx=np.array([[2,-1],[-1,2]])
ex=np.linalg.eig(sx)
print(ex)
# Out:
# (array([3., 1.]), array([[ 0.70710678,  0.70710678],
#        [-0.70710678,  0.70710678]]))

# %% [markdown]
# eigenvalue에 의해서 w가 결정되고 eigenvector는 진폭을 의미한다.

# %% [markdown]
# -7
