# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f_vibration():
    m=1
    k=1
    C=1
    N=40
    d=2*k-m*w**2
    w=frequancy
    M=np.zeros((40, 40))
    b=np.zeros((40, 1))
    b[0,0]=C
    for i in range(40) : 
        M[0,0]=d-k
        M[i,i]=d
        M[i,i+1]=-k
        M[i+1,i]=-k
        M[39,39]=d-k
    a=np.dot(np.linalg.inv(M),b)
    return a

# %%
x=np.arange(1,40,1)
plt.plot()
plt.xlabel('i')
plt.ylabel('$a_i$')
plt.show()

# %%
x=np.arange(1,40,1)
plt.plot()
plt.xlabel('i')
plt.ylabel('$a_i$')
plt.show()

# %%
def f_vibration():
    m=1
    k=1
    C=1
    N=40
    d=2*k-m*w**2
    w=frequancy
    M=np.zeros((40, 40))
    b=np.zeros((40, 1))
    b[0,0]=C
    b[39,0]=C
    for i in range(39) : 
        M[0,0]=d-k
        M[i,i]=d
        M[i,i+1]=-k
        M[i+1,i]=-k
        M[39,39]=d-k
    a=np.dot(np.linalg.inv(M),b)
    return a

# %%
x=np.arange(1,40,1)
plt.plot()
plt.xlabel('i')
plt.ylabel('$a_i$')
plt.show()

# %%
x=np.arange(1,40,1)
plt.plot()
plt.xlabel('i')
plt.ylabel('$a_i$')
plt.show()

# %% [markdown]
# 함수라도 제대로 작성했으면 점수를 주려 했는데 안타깝지만 -10
