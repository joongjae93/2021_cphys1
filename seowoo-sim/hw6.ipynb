# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint

# %%
ratio=1
state=[0,1] 
t = np.arange(0.0, 100, 0.01)

# %%
def f1(state,t):
    theta,omega=state
    return omega,-ratio*np.sin(theta)

# %%
sol1=odeint(f1,state,t)
plt.plot(t,sol1[:,0],label=r'$\theta (t)$')
plt.legend()
plt.ylabel(r'$ \theta$')
plt.xlabel('$t$')
plt.show()

# %%
def f2(state,t):
    theta,omega=state
    return omega,-ratio*theta

# %%
sol2=odeint(f2,[0,1],t)
plt.plot(t,sol2[:,0],label=r'$small oscillations$')
plt.legend()
plt.ylabel(r'$ \theta$')
plt.xlabel('$t$')
plt.show()

# %%
beta=0.1

# %%
def f3(state,t):
    theta,omega=state
    return omega,-beta*omega-ratio*np.sin(theta)

# %%
sol3=odeint(f3,[1,0],t)
plt.plot(t,sol[:,0])
plt.ylabel(r'$ \theta$')
plt.xlabel('$t$')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-3f9d7f9ea1e8> in <module>
#       1 sol3=odeint(f3,[1,0],t)
# ----> 2 plt.plot(t,sol[:,0])
#       3 plt.ylabel(r'$ \theta$')
#       4 plt.xlabel('$t$')
#       5 plt.show()
#
# NameError: name 'sol' is not defined

# %% [markdown]
# -7
