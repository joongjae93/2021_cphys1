# %%
import numpy as np
import sympy
from sympy import Symbol
sympy.init_printing(use_latex='mathjax')

# %% [markdown]
# ## Gaussian Integral

# %% [markdown]
# sympy를 이용하여 다음 적분들을 계산하세요.
#
# 1. $ \int_{-\infty}^{\infty} e^{-ax^2} dx $

# %%
x,a = sympy.symbols("x,a")
sympy.integrate(sympy.exp(-a*x**2), (x,-1*sympy.oo,sympy.oo))
# Out:
# ⎧     √π           π
# ⎪     ──       for ─ ≥ │arg(a)│
# ⎪     √a           2
# ⎪
# ⎪∞
# ⎨⌠
# ⎪⎮       2
# ⎪⎮   -a⋅x
# ⎪⎮  ℯ      dx     otherwise
# ⎪⌡
# ⎩-∞

# %% [markdown]
# 2. $ \int_{-\infty}^{\infty} x e^{-ax^2} dx $

# %%
sympy.integrate(x*sympy.exp(-a*x**2), (x,-1*sympy.oo,sympy.oo))
# Out:
# ⎧                    π
# ⎪      0         for ─ > │arg(a)│
# ⎪                    2
# ⎪
# ⎪∞
# ⎨⌠
# ⎪⎮         2
# ⎪⎮     -a⋅x
# ⎪⎮  x⋅ℯ      dx     otherwise
# ⎪⌡
# ⎩-∞

# %% [markdown]
# 3. $ \int_{-\infty}^{\infty} x^2 e^{-ax^2} dx $

# %%
sympy.integrate((x**2)*sympy.exp(-a*x**2), (x,-1*sympy.oo,sympy.oo))
# Out:
# ⎧      √π             π
# ⎪    ──────       for ─ > │arg(a)│
# ⎪       3/2           2
# ⎪    2⋅a
# ⎪
# ⎪∞
# ⎨⌠
# ⎪⎮          2
# ⎪⎮   2  -a⋅x
# ⎪⎮  x ⋅ℯ      dx     otherwise
# ⎪⌡
# ⎪-∞
# ⎩

# %% [markdown]
# 4. $ \int_{-\infty}^{\infty} x^4 e^{-ax^2} dx $

# %%
sympy.integrate((x**4)*sympy.exp(-a*x**2), (x,-1*sympy.oo,sympy.oo))
# Out:
# ⎧     3⋅√π            π
# ⎪    ──────       for ─ > │arg(a)│
# ⎪       5/2           2
# ⎪    4⋅a
# ⎪
# ⎪∞
# ⎨⌠
# ⎪⎮          2
# ⎪⎮   4  -a⋅x
# ⎪⎮  x ⋅ℯ      dx     otherwise
# ⎪⌡
# ⎪-∞
# ⎩

# %% [markdown]
# ## 미분방정식

# %% [markdown]
# sympy를 이용해서 다음의 간단한 미분방정식을 풀어보세요.
#
# $$ x'(t)=- a x.$$
#
# 초기조건은 다음과 같다. $x(0)=1$.

# %%
t,a = sympy.symbols('t,a')
x = Function('x')
x, x(t).diff(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-60f2babeef23> in <module>
#       1 t,a = sympy.symbols('t,a')
# ----> 2 x = Function('x')
#       3 x, x(t).diff(t)
#
# NameError: name 'Function' is not defined

# %%
Eq(x(t).diff(t),-a*x(t))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a4881149ce13> in <module>
# ----> 1 Eq(x(t).diff(t),-a*x(t))
#
# NameError: name 'Eq' is not defined

# %%
dsolve(Eq(x(t).diff(t),-a*x(t)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-b4c8764d852f> in <module>
# ----> 1 dsolve(Eq(x(t).diff(t),-a*x(t)))
#
# NameError: name 'dsolve' is not defined

# %%
psol = dsolve( Eq(x(t).diff(t),-a*x(t)), ics= {x(0):1} )
psol
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-1779889fe744> in <module>
# ----> 1 psol = dsolve( Eq(x(t).diff(t),-a*x(t)), ics= {x(0):1} )
#       2 psol
#
# NameError: name 'dsolve' is not defined

# %%
-5
