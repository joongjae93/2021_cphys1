# %% [markdown]
# ## 1. Leibniz Pi formula

# %% [markdown]
# 1. 식을 구현하는 함수 구현

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def f(n):
    f=0
    for i in range(1, n+1):
        f=f+((-1)**(i+1))*1/(2*i-1)
    return f

# %% [markdown]
# 2. 이 식을 이용하여 그래프 그리기

# %%
def f(n):
    f=0
    for i in range(1, n+1):
        f=f+((-1)**(i+1))*1/(2*i-1)
    return f

# %%
a = [f(n) for n in range (1,101)]
plt.plot(a,color='skyblue',label='Leibniz Pi')
plt.hlines(np.pi/4,0,100,color='orange',label='π/4')
plt.legend()

# %% [markdown]
# ## Logistic Map

# %% [markdown]
# 1. $f_n$을 구하는 함수를 작성하여라.

# %%
def f(r,s):
    fn=[]
    for n in range(1,100):
        y=r*s*(1-s)
        fn.append(s)
    return fn

# %% [markdown]
# 2. 작성한 함수를 이용하여 $n=1$에서 $100$까지 로지스틱 맵의 값을 구하고 그래프로 그려라. 즉, x축은 $n$, y축은 $f_n$인 그래프를 그려라.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(r,s):
    fn=[]
    for n in range(1,100):
        s=r*s*(1-s)
        fn.append(s)
    return fn

# %%
f(0.5,0.5)
# Out:
# [0.125,
#  0.0546875,
#  0.025848388671875,
#  0.012590124737471342,
#  0.006215806748283127,
#  0.0030885852473755623,
#  0.0015395229442726282,
#  0.0007685764066883431,
#  0.00038399284849771257,
#  0.0001919226989950076,
#  9.594293233630902e-05,
#  4.7966863645021866e-05,
#  2.3982281412506963e-05,
#  1.1990853131342606e-05,
#  5.9953546753918944e-06,
#  2.9976593655571054e-06,
#  1.4988251897977167e-06,
#  7.494114716603835e-07,
#  3.747054550214148e-07,
#  1.873526573086184e-07,
#  9.36763111038001e-08,
#  4.683815116427442e-08,
#  2.341907448523101e-08,
#  1.170953696838898e-08,
#  5.854768415637862e-09,
#  2.9273841906797743e-09,
#  1.463692091055098e-09,
#  7.318460444563517e-10,
#  3.6592302196037656e-10,
#  1.8296151091323845e-10,
#  9.148075543988177e-11,
#  4.574037771575652e-11,
#  2.2870188856832168e-11,
#  1.1435094428154562e-11,
#  5.717547214011901e-12,
#  2.858773606989605e-12,
#  1.4293868034907161e-12,
#  7.146934017443365e-13,
#  3.573467008719129e-13,
# ...

# %%
plt.plot(f(0.5,0.5))
plt.xlabel('n')
plt.ylabel('$f_n$')
# Out:
# Text(0, 0.5, '$f_n$')

# %%
f(0.95, 0.5)
# Out:
# [0.2375,
#  0.17203906249999998,
#  0.135319542300415,
#  0.11115775558342016,
#  0.09386162350922293,
#  0.08079903818436403,
#  0.07055702593220342,
#  0.062299795422615496,
#  0.05549760436726996,
#  0.04979673926292574,
#  0.04495117282062064,
#  0.04078403663853777,
#  0.03716466404430396,
#  0.03399427920123908,
#  0.031196734773685918,
#  0.028712323587488903,
#  0.02649352975861142,
#  0.02450204150756394,
#  0.022706606896049274,
#  0.021081466054351683,
#  0.019605185951183355,
#  0.018259781503252734,
#  0.017030043788570894,
#  0.01590302032727374,
#  0.014867608558156855,
#  0.013914234635222362,
#  0.013034597274251422,
#  0.012221461720742025,
#  0.011468492714442939,
#  0.010770118069836621,
#  0.01012141649526848,
#  0.009518024752227898,
#  0.008956060359191682,
#  0.008432056874932486,
#  0.00794290942720087,
#  0.007485828636180546,
#  0.007058301455519771,
#  0.006658057744278639,
#  0.006283041610784866,
#  0.005931386748956911,
#  0.005601395130181649,
# ...

# %%
plt.plot(f(0.95,0.5))
plt.xlabel('n')
plt.ylabel('$f_n$')
# Out:
# Text(0, 0.5, '$f_n$')

# %%
f(2,0.5)
# Out:
# [0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5,
#  0.5]

# %%
plt.plot(f(2,0.5))
plt.xlabel('n')
plt.ylabel('$f_n$')
# Out:
# Text(0, 0.5, '$f_n$')

# %%
f(3.2,0.5)
# Out:
# [0.8,
#  0.512,
#  0.7995392,
#  0.512884056522752,
#  0.7994688034800593,
#  0.5130189943751092,
#  0.7994576185134749,
#  0.5130404310855622,
#  0.7994558309027286,
#  0.5130438570827405,
#  0.7994555449356961,
#  0.5130444051432489,
#  0.7994554991822682,
#  0.5130444928303954,
#  0.7994554918617529,
#  0.5130445068602741,
#  0.7994554906904713,
#  0.5130445091050531,
#  0.7994554905030663,
#  0.5130445094642175,
#  0.7994554904730814,
#  0.5130445095216841,
#  0.7994554904682839,
#  0.5130445095308785,
#  0.7994554904675163,
#  0.5130445095323497,
#  0.7994554904673934,
#  0.5130445095325852,
#  0.7994554904673739,
#  0.5130445095326227,
#  0.7994554904673707,
#  0.5130445095326286,
#  0.7994554904673701,
#  0.5130445095326298,
#  0.7994554904673701,
#  0.5130445095326298,
#  0.7994554904673701,
#  0.5130445095326298,
#  0.7994554904673701,
#  0.5130445095326298,
#  0.7994554904673701,
#  0.5130445095326298,
#  0.7994554904673701,
#  0.5130445095326298,
#  0.7994554904673701,
# ...

# %%
plt.plot(f(3.2,0.5))
plt.xlabel('n')
plt.ylabel('$f_n$')
# Out:
# Text(0, 0.5, '$f_n$')

# %%
f(3.8,0.5)
# Out:
# [0.95,
#  0.18050000000000016,
#  0.5620950500000005,
#  0.9353479781088904,
#  0.22979412423470422,
#  0.6725573818672562,
#  0.8368510098598481,
#  0.5188193091943221,
#  0.9486541676855043,
#  0.1850958637100242,
#  0.5731744628003645,
#  0.9296528923767365,
#  0.2485138898747569,
#  0.7096679983734816,
#  0.7829494557406192,
#  0.6457705008851319,
#  0.8692536520724515,
#  0.43187661363839625,
#  0.932364976076385,
#  0.23963000435737464,
#  0.6923883684024251,
#  0.8093495196731204,
#  0.5863509237764368,
#  0.9216653682592327,
#  0.2743536054010614,
#  0.7565180774971003,
#  0.6999542084853282,
#  0.7980695951342224,
#  0.6123871625347789,
#  0.9020026776500485,
#  0.3358966192163266,
#  0.8476663055784008,
#  0.4906869318687708,
#  0.9496704136955357,
#  0.18162677237816585,
#  0.5648262541478919,
#  0.9340307157379811,
#  0.23414588362470812,
#  0.6814220374639884,
#  0.8249269684251775,
#  0.5488053677220899,
#  0.940948537109744,
#  0.21114467295895145,
# ...

# %%
plt.plot(f(3.8,0.5))
plt.xlabel('n')
plt.ylabel('$f_n$')
# Out:
# Text(0, 0.5, '$f_n$')

# %%
f(3.8,0.501)
# Out:
# [0.9499962,
#  0.18051299594512815,
#  0.5621266061121607,
#  0.9353330822893409,
#  0.22984340836495548,
#  0.672658580785316,
#  0.8367182550285618,
#  0.5191591035759776,
#  0.9486051292506268,
#  0.18526306443810803,
#  0.5735745132938159,
#  0.9294298057755966,
#  0.2492421592638267,
#  0.7110579201754613,
#  0.7807273064585927,
#  0.6505302817523129,
#  0.8638944102471634,
#  0.4468072611253027,
#  0.9392480236178316,
#  0.21683246024174982,
#  0.6453013488235873,
#  0.8697725685141756,
#  0.43041934078283134,
#  0.931602421079036,
#  0.24213353045111505,
#  0.6973185587530971,
#  0.8020484682120821,
#  0.6033135468327924,
#  0.909439981955148,
#  0.3129638244709588,
#  0.8170663823651848,
#  0.5679818548606468,
#  0.9324381761568826,
#  0.239389450448014,
#  0.691912137556405,
#  0.8100449795424196,
#  0.5847140205100543,
#  0.9227294319702839,
#  0.27093934391510827,
#  0.750618620169044,
#  0.7113231674533448,
#  0.7803015718104452,
#  0.6514379095942564,
# ...

# %%
plt.plot(f(3.8,0.501))
plt.xlabel('n')
plt.ylabel('$f_n$')
# Out:
# Text(0, 0.5, '$f_n$')

# %% [markdown]
# ## 3. sinc function

# %% [markdown]
# 1. 싱크 함수를 그려보아라.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.arange(-15,15,0.01)
b = [np.sin(x)/x for x in a]

plt.plot(a,b)

# %% [markdown]
# 2. 싱크함수 테일러 전개식의 우변을 $n$을 바꾸어 가면서 그래프로 그리고 싱크함수와 비교하여라.

# %%
def f(x,n):
    y = 0
    for i in range(n+1):
        y=y+(((-1)**(i))*(x**(2*i)))/(math.factorial(2*i+1))
    return y

x = np.arange(-15,15,0.01)
plt.plot(x,f(x,1),color='red')
plt.plot(x,f(x,4),color='orange')
plt.plot(x,f(x,9),color='yellow')
plt.plot(x,f(x,16),color='green')
plt.plot(x,f(x,25),color='blue')
plt.axis([-15, 15, -2, 2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-596c972bc445> in <module>
#       6
#       7 x = np.arange(-15,15,0.01)
# ----> 8 plt.plot(x,f(x,1),color='red')
#       9 plt.plot(x,f(x,4),color='orange')
#      10 plt.plot(x,f(x,9),color='yellow')
#
# <ipython-input-3-596c972bc445> in f(x, n)
#       2     y = 0
#       3     for i in range(n+1):
# ----> 4         y=y+(((-1)**(i))*(x**(2*i)))/(math.factorial(2*i+1))
#       5     return y
#       6
#
# NameError: name 'math' is not defined

# %% [markdown]
# 싱크 함수(-1) - import math 가 없음.
#
# 공지했다시피 다음 과제부턴 위와 같이 문법 오류가 발생할 경우 해당 부분은 0점 처리될 것입니다.
