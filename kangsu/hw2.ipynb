# %% [markdown]
# # Logistic Map (part 2)

# %% [markdown]
# $f_n$을 구하는 함수를 작성하여라.

# %%
def Logistic(r,f,n1):
    f2=f
    for i in range(0, n1):
        f2=r*f2*(1-f2)
        
    return f2

# %% [markdown]
# 작성한 함수를 이용하여 다음의 조건에서 $n=1$에서 $20$까지 로지스틱 맵의 값을 구하여라.
#
# $r=4.5$, $f_0$=0.5
#
# $r=4.5$, $f_0$=0.51
#
# $r=4.5$, $f_0$=0.501

# %%
r0=[4.5,4.5,4.5]
f0=[0.5,0.51,0.501]
n=20

for k in range(0, 3):
    r = r0[k]
    f = f0[k]
    print('\n')
    print('\n')
    print('r=',r,'f=',f)
    print('\n')
    for j in range(1, n+1):
        fp = Logistic(r,f,j)
        print('n',j,':',fp)
# Out:
# r= 4.5 f= 0.5
#
#
# n 1 : 1.125
# n 2 : -0.6328125
# n 3 : -4.649688720703125
# n 4 : -118.21182264061645
# n 5 : -63415.11075595729
# n 6 : -18096928592.854885
# n 7 : -1.4737447103084353e+21
# n 8 : -9.773655620229423e+42
# n 9 : -4.298595488227898e+86
# n 10 : -8.315065427135959e+173
# n 11 : -inf
# n 12 : -inf
# n 13 : -inf
# n 14 : -inf
# n 15 : -inf
# n 16 : -inf
# n 17 : -inf
# n 18 : -inf
# n 19 : -inf
# n 20 : -inf
#
#
#
#
# r= 4.5 f= 0.51
#
#
# n 1 : 1.12455
# n 2 : -0.6302821612499996
# n 3 : -4.623919938179865
# n 4 : -117.0204998979472
# n 5 : -62148.68053318534
# n 6 : -17381342883.134087
# n 7 : -1.359499861973058e+21
# n 8 : -8.317079436171436e+42
# n 9 : -3.11282146564136e+86
# n 10 : -4.360345864630932e+173
# n 11 : -inf
# n 12 : -inf
# n 13 : -inf
# n 14 : -inf
# n 15 : -inf
# n 16 : -inf
# n 17 : -inf
# n 18 : -inf
# n 19 : -inf
# n 20 : -inf
#
#
#
#
# r= 4.5 f= 0.501
#
#
# n 1 : 1.1249955
# n 2 : -0.6327871875911253
# n 3 : -4.649430655667751
# n 4 : -118.19986234888862
# n 5 : -63402.33294740298
# n 6 : -18089636514.7783
# n 7 : -1.4725572716470052e+21
# n 8 : -9.757912132262123e+42
# n 9 : -4.2847582131426745e+86
# n 10 : -8.261618825292122e+173
# n 11 : -inf
# n 12 : -inf
# n 13 : -inf
# n 14 : -inf
# n 15 : -inf
# n 16 : -inf
# n 17 : -inf
# n 18 : -inf
# n 19 : -inf
# n 20 : -inf

# %% [markdown]
# # 피보나치 수 (Fibonacci numbers)

# %%
def Fibonacci(n):
    f=[1,1]

    if n>2:
        for i in range(2,n):
            h=f[i-2]+f[i-1]
            f.append(h)
    fr=f
    return fr

# %%
n=10
Fibonacci(n)
print('n=',n)
for j in range(n):
    print(f[j],', ',end='')
print('...')
# Out:
# n= 10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-4bd08e1d176c> in <module>
#       3 print('n=',n)
#       4 for j in range(n):
# ----> 5     print(f[j],', ',end='')
#       6 print('...')
#
# TypeError: 'float' object is not subscriptable

# %%
마지막 셀은 실행되지 않으나 어찌됐든 과제는 함수를 작성하는 것 까지였으므로 일단은 감점 x
