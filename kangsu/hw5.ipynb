# %% [markdown]
# # 1. Vibration in a one-dimensional system
#
# $m=1$, $k=1$, $C=1$, $N=40$으로 고정하세요.
#
# $w$ (즉, d)를 바꾸어가면서 $a_i$를 구하세요.
#
# 이를 그래프로 표현하고 의미를 설명하세요. x축이 i (1~N), y축이 $a_i$

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def af(d):

    m=1
    k=1
    c=1
    n=40
    M = np.identity(n)
    M=d*M
    
    M[0,0]=M[0,0]-k
    M[39,39]=M[39,39]-k

    for i in range(0,n):
        for j in range(0,n):
            if i+1==j:
                M[i,j]=M[i,j]-k
            if i==j+1:
                M[i,j]=M[i,j]-k
    
        

    MI=np.linalg.inv(M)

    b=np.zeros(n)
    b[0]=c
    a=np.dot(MI,b)

    ndata=np.arange(0,n,1)

    plt.plot(ndata,a,'o',label="$a_n$ \n d=%f"%(d))
    plt.legend()
    plt.xlabel("n")
    plt.ylabel("$a_n$")
    plt.show()
    
    return 0
 
for i in range(1,20):
    af(1+i/20)

# %% [markdown]
# $a_n$은 원래의 각각의 질량 m의 각각의 초기 기준점으로 부터 x축으로의 상대적인 움직임의 차이을 나타낸것이다.
# n은 해당 질량의 고유 번호다

# %% [markdown]
# # 2. 양쪽 끝에서 힘을 가하면 어떻게 되는가?
#
# 즉, b행렬이 다음과 같은 경우에 대해서 살펴보아라.$$
# b=
# \begin{pmatrix}
# C \\
# 0 \\
# 0 \\
# \cdots \\
# C
# \end{pmatrix}
# $$
#
# $m=1$, $k=1$, $C=1$, $N=40$으로 고정하세요.
#
# $w$ (즉, d)를 바꾸어가면서 $a_i$를 구하세요.
#
# 이를 그래프로 표현하고 의미를 설명하세요.

# %%
def af(d):

    m=1
    k=1
    c=1
    n=40
    M = np.identity(n)
    M=d*M
    
    M[0,0]=M[0,0]-k
    M[39,39]=M[39,39]-k

    for i in range(0,n):
        for j in range(0,n):
            if i+1==j:
                M[i,j]=M[i,j]-k
            if i==j+1:
                M[i,j]=M[i,j]-k
    
        

    MI=np.linalg.inv(M)

    b=np.zeros(n)
    b[0]=c
    b[n-1]=c
    a=np.dot(MI,b)

    ndata=np.arange(0,n,1)

    plt.plot(ndata,a,'o',label="$a_n$ \n d=%f"%(d))
    plt.legend()
    plt.xlabel("n")
    plt.ylabel("$a_n$")
    plt.show()
    
    return 0
 
for i in range(1,20):
    af(1+i/20)

# %% [markdown]
# 양쪽에서 같은 힘을 받아
# 중심을 기준으로 대칭적인 움직임을 보인다

# %% [markdown]
# 그래프를 알아보기가 어렵고 그래프가 담고 있는 정보는 진폭일 뿐 motion 이 아님.(-1.5)
