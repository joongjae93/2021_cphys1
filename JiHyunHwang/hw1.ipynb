# %%
r = [0.5, 2.5, 4.5, 4.5]
f = [0.5, 0.5, 0.5, 0.51]

a = 0
b = -1
for i in f:
    a = 0
    b += 1
    while a < 10:
        a += 1
        i = r[b]*i*(1-i)
        print("r,f가",r[b],",",f[b],"일때",a,"번째 반복된값:", i)
# Out:
# r,f가 0.5 , 0.5 일때 1 번째 반복된값: 0.125
# r,f가 0.5 , 0.5 일때 2 번째 반복된값: 0.0546875
# r,f가 0.5 , 0.5 일때 3 번째 반복된값: 0.025848388671875
# r,f가 0.5 , 0.5 일때 4 번째 반복된값: 0.012590124737471342
# r,f가 0.5 , 0.5 일때 5 번째 반복된값: 0.006215806748283127
# r,f가 0.5 , 0.5 일때 6 번째 반복된값: 0.0030885852473755623
# r,f가 0.5 , 0.5 일때 7 번째 반복된값: 0.0015395229442726282
# r,f가 0.5 , 0.5 일때 8 번째 반복된값: 0.0007685764066883431
# r,f가 0.5 , 0.5 일때 9 번째 반복된값: 0.00038399284849771257
# r,f가 0.5 , 0.5 일때 10 번째 반복된값: 0.0001919226989950076
# r,f가 2.5 , 0.5 일때 1 번째 반복된값: 0.625
# r,f가 2.5 , 0.5 일때 2 번째 반복된값: 0.5859375
# r,f가 2.5 , 0.5 일때 3 번째 반복된값: 0.606536865234375
# r,f가 2.5 , 0.5 일때 4 번째 반복된값: 0.5966247408650815
# r,f가 2.5 , 0.5 일때 5 번째 반복된값: 0.6016591486318896
# r,f가 2.5 , 0.5 일때 6 번째 반복된값: 0.5991635437485985
# r,f가 2.5 , 0.5 일때 7 번째 반복된값: 0.6004164789780495
# r,f가 2.5 , 0.5 일때 8 번째 반복된값: 0.5997913268741273
# r,f가 2.5 , 0.5 일때 9 번째 반복된값: 0.6001042277017528
# r,f가 2.5 , 0.5 일때 10 번째 반복된값: 0.599947858990589
# ...

# %%
# Out:
# F 1 0.125
# F 2 0.0546875
# F 3 0.025848388671875
# F 4 0.012590124737471342
# F 5 0.006215806748283127
# F 6 0.0030885852473755623
# F 7 0.0015395229442726282
# F 8 0.0007685764066883431
# F 9 0.00038399284849771257
# F 10 0.0001919226989950076
# F 1 0.625
# F 2 0.5859375
# F 3 0.606536865234375
# F 4 0.5966247408650815
# F 5 0.6016591486318896
# F 6 0.5991635437485985
# F 7 0.6004164789780495
# F 8 0.5997913268741273
# F 9 0.6001042277017528
# F 10 0.599947858990589
# F 1 1.125
# F 2 -0.6328125
# F 3 -4.649688720703125
# F 4 -118.21182264061645
# F 5 -63415.11075595729
# F 6 -18096928592.854885
# F 7 -1.4737447103084353e+21
# F 8 -9.773655620229423e+42
# F 9 -4.298595488227898e+86
# F 10 -8.315065427135959e+173
# F 1 1.12455
# F 2 -0.6302821612499996
# F 3 -4.623919938179865
# F 4 -117.0204998979472
# F 5 -62148.68053318534
# F 6 -17381342883.134087
# F 7 -1.359499861973058e+21
# F 8 -8.317079436171436e+42
# F 9 -3.11282146564136e+86
# F 10 -4.360345864630932e+173
