# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
#싱크함수 sinc(x)
x = np.linspace(-4, 4, 41)
np.sinc(x)
plt.plot(x, np.sinc(x))

# %%
#sinc function
def sincx(x,n):
    i,f = 0, 0
    while(i<=n+1):
        f = f+((-1)**i*x**(2*i))/math.factorial(2*i+1)
        i += 1
    return f

x = np.linspace(-20,20,100)
plt.plot(x,sincx(x,1),label="$N=1$")
plt.plot(x,sincx(x,2**2),label="$N=2$")
plt.plot(x,sincx(x,2**3),label="$N=3$")
plt.plot(x,sincx(x,2**4),label="$N=4$")
plt.grid()
plt.legend();
plt.axis([-20,20,-0.3,1.1])
# Out:
# [-20, 20, -0.3, 1.1]
