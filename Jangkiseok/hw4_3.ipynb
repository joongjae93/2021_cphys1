# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import integrate

# %%
#scipy.integrate 
#1)sin(x)
def f(x):
    return np.sin(x)
integrate.quad(f,0,np.pi)
# Out:
# (2.0, 2.220446049250313e-14)

# %%
xdata = np.arange(0,np.pi*2,0.01)
def f(x):
    return np.sin(x)

plt.xlim(0,np.pi*2);plt.ylim(-2,2)
plt.plot(xdata,f(xdata));

# %%
#2)cos(x)
def f(x):
    return np.cos(x)
integrate.quad(f,0,np.pi)
# Out:
# (3.6775933888827275e-17, 2.2102239425853306e-14)

# %%
xdata = np.arange(0,np.pi*2,0.01)
def f(x):
    return np.cos(x)

plt.xlim(0,np.pi*2);plt.ylim(-2,2)
plt.plot(xdata,f(xdata));

# %% [markdown]
# 4_2 와 동일 (-1)
