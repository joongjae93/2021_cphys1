# %%
def logstic(r,f,):
    r = 4.5
    f = 0.5
    for n in range(20):
        n = n+1
        print(n)
        f = r*f*(1-f)
        print(f)
logstic(4.5, 0.5),logstic(4.5, 0.51), logstic(4.5, 0.501)
# Out:
# 1
# 1.125
# 2
# -0.6328125
# 3
# -4.649688720703125
# 4
# -118.21182264061645
# 5
# -63415.11075595729
# 6
# -18096928592.854885
# 7
# -1.4737447103084353e+21
# 8
# -9.773655620229423e+42
# 9
# -4.298595488227898e+86
# 10
# -8.315065427135959e+173
# 11
# -inf
# 12
# -inf
# 13
# -inf
# 14
# -inf
# 15
# -inf
# 16
# -inf
# 17
# -inf
# 18
# -inf
# 19
# -inf
# 20
# -inf
# 1
# 1.125
# 2
# -0.6328125
# 3
# -4.649688720703125
# 4
# -118.21182264061645
# 5
# -63415.11075595729
# 6
# -18096928592.854885
# 7
# -1.4737447103084353e+21
# 8
# -9.773655620229423e+42
# 9
# -4.298595488227898e+86
# 10
# -8.315065427135959e+173
# 11
# -inf
# 12
# -inf
# 13
# -inf
# 14
# -inf
# 15
# -inf
# 16
# -inf
# 17
# -inf
# 18
# -inf
# 19
# -inf
# 20
# -inf
# 1
# 1.125
# 2
# -0.6328125
# 3
# -4.649688720703125
# 4
# -118.21182264061645
# 5
# -63415.11075595729
# 6
# -18096928592.854885
# 7
# -1.4737447103084353e+21
# 8
# -9.773655620229423e+42
# 9
# -4.298595488227898e+86
# 10
# -8.315065427135959e+173
# 11
# ...

# %% [markdown]
# 로지스틱(-3)
