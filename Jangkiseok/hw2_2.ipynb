# %%
def fibo(n):
    a,b = 1,1
    if n==1 or n==2:
        return1 
        
    for i in range(1,n):
        a,b = b, a+b
    return a 
fibo(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-c68460d2302c> in <module>
#       7         a,b = b, a+b
#       8     return a
# ----> 9 fibo(2)
#
# <ipython-input-4-c68460d2302c> in fibo(n)
#       2     a,b = 1,1
#       3     if n==1 or n==2:
# ----> 4         return1
#       5
#       6     for i in range(1,n):
#
# NameError: name 'return1' is not defined

# %% [markdown]
# 피보나치(-1.5) return1 -> return 1
