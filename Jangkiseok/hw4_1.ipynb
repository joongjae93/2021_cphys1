# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import integrate
import math

# %%
def F(x):
    return 2/np.pi*np.exp(-x**2)

integrate.quad(F,0,8)
# Out:
# (0.5641895835477564, 8.39086872090296e-09)

# %%
x=np.arange(0,20,5)
ydata=np.array([trapez(F,0,6,i) for i in xdata])
plt.plot(xdata.F)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1aaf2548beeb> in <module>
#       1 x=np.arange(0,20,5)
# ----> 2 ydata=np.array([trapez(F,0,6,i) for i in xdata])
#       3 plt.plot(xdata.F)
#
# NameError: name 'xdata' is not defined

# %%
#에러함수 테일러 전개
def F(x):
    return 2/np.pi*(x**(2i+1)*(-1)**i)/(2i+1)*(math.factorial(n)
# Out:
#   File "<ipython-input-6-2cda3ac95d67>", line 3
#     return 2/np.pi*(x**(2i+1)*(-1)**i)/(2i+1)*(math.factorial(n)
#                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# (-3)
