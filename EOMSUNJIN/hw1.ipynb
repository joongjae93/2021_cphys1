# %%
def f(r,f_0):
    for i in range(11):
        f_n=r*f_0*(1-f_0)
        print(f_n)
        f_0=f_n

print('초기조건 r=0.5,f_0=0.5일때')
f(0.5,0.5)

print('초기조건 r=2.5,f_0=0.5일때')
f(2.5,0.5)

print('초기조건 r=4.5,f_0=0.5일때')
f(4.5,0.5)

print('초기조건 r=4.5,f_0=0.51일때')
f(4.5,0.51)
# Out:
# 초기조건 r=0.5,f_0=0.5일때
# 0.125
# 0.0546875
# 0.025848388671875
# 0.012590124737471342
# 0.006215806748283127
# 0.0030885852473755623
# 0.0015395229442726282
# 0.0007685764066883431
# 0.00038399284849771257
# 0.0001919226989950076
# 9.594293233630902e-05
# 초기조건 r=2.5,f_0=0.5일때
# 0.625
# 0.5859375
# 0.606536865234375
# 0.5966247408650815
# 0.6016591486318896
# 0.5991635437485985
# 0.6004164789780495
# 0.5997913268741273
# 0.6001042277017528
# 0.599947858990589
# 0.6000260637079934
# 초기조건 r=4.5,f_0=0.5일때
# 1.125
# -0.6328125
# -4.649688720703125
# -118.21182264061645
# -63415.11075595729
# -18096928592.854885
# -1.4737447103084353e+21
# -9.773655620229423e+42
# -4.298595488227898e+86
# -8.315065427135959e+173
# -inf
# 초기조건 r=4.5,f_0=0.51일때
# 1.12455
# -0.6302821612499996
# -4.623919938179865
# -117.0204998979472
# -62148.68053318534
# -17381342883.134087
# -1.359499861973058e+21
# -8.317079436171436e+42
# -3.11282146564136e+86
# -4.360345864630932e+173
# -inf
